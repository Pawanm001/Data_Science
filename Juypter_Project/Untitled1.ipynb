# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
hr_Test =pd.read_csv("HR_comma_sep.csv")

# %%
hr_Test.head(10)
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
# 2                0.11             0.88               7                   272
# 3                0.72             0.87               5                   223
# 4                0.37             0.52               2                   159
# 5                0.41             0.50               2                   153
# 6                0.10             0.77               6                   247
# 7                0.92             0.85               5                   259
# 8                0.89             1.00               5                   224
# 9                0.42             0.53               2                   142
#
#    time_spend_company  Work_accident  left  promotion_last_5years  sales  \
# ...

# %%
hr_Test.describe()
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# count        14999.000000     14999.000000    14999.000000
# mean             0.612834         0.716102        3.803054
# std              0.248631         0.171169        1.232592
# min              0.090000         0.360000        2.000000
# 25%              0.440000         0.560000        3.000000
# 50%              0.640000         0.720000        4.000000
# 75%              0.820000         0.870000        5.000000
# max              1.000000         1.000000        7.000000
#
#        average_montly_hours  time_spend_company  Work_accident          left  \
# count          14999.000000        14999.000000   14999.000000  14999.000000
# mean             201.050337            3.498233       0.144610      0.238083
# std               49.943099            1.460136       0.351719      0.425924
# min               96.000000            2.000000       0.000000      0.000000
# ...

# %%
hr_Test.shape
# Out:
# (14999, 10)

# %%
hr_Test.isnull().any()
# Out:
# satisfaction_level       False
# last_evaluation          False
# number_project           False
# average_montly_hours     False
# time_spend_company       False
# Work_accident            False
# left                     False
# promotion_last_5years    False
# sales                    False
# salary                   False
# dtype: bool

# %%
hr_Test["Left"] = hr_Test["left"]

# %%
front = hr_Test["Left"]
hr_Test.drop(labels=["Left"],axis=1,inplace=True)
hr_Test.insert(0,"Left",front)

# %%
hr_Test.head()
# Out:
#    Left  satisfaction_level  last_evaluation  number_project  \
# 0     1                0.38             0.53               2
# 1     1                0.80             0.86               5
# 2     1                0.11             0.88               7
# 3     1                0.72             0.87               5
# 4     1                0.37             0.52               2
#
#    average_montly_hours  time_spend_company  Work_accident  \
# 0                   157                   3              0
# 1                   262                   6              0
# 2                   272                   4              0
# 3                   223                   5              0
# 4                   159                   3              0
#
#    promotion_last_5years  sales  salary
# 0                      0  sales     low
# 1                      0  sales  medium
# 2                      0  sales  medium
# 3                      0  sales     low
# ...

# %%
hr_Test.Left.value_counts()
# Out:
# 0    11428
# 1     3571
# Name: Left, dtype: int64

# %%
hr_Test.Left.value_counts().plot(kind="Pie")

# %%
hr_Test.salary.value_counts()
# Out:
# low       7316
# medium    6446
# high      1237
# Name: salary, dtype: int64

# %%
hr_Test.salary.value_counts().plot(kind="bar")

# %%
Left_summary = hr_Test.groupby("Left")
Left_summary.mean()
# Out:
#       satisfaction_level  last_evaluation  number_project  \
# Left
# 0               0.666810         0.715473        3.786664
# 1               0.440098         0.718113        3.855503
#
#       average_montly_hours  time_spend_company  Work_accident  \
# Left
# 0               199.060203            3.380032       0.175009
# 1               207.419210            3.876505       0.047326
#
#       promotion_last_5years
# Left
# 0                  0.026251
# 1                  0.005321

# %%
hr_Test.sales.value_counts()
# Out:
# sales          4140
# technical      2720
# support        2229
# IT             1227
# product_mng     902
# marketing       858
# RandD           787
# accounting      767
# hr              739
# management      630
# Name: sales, dtype: int64

# %%
hr_Test.sales.value_counts().plot(kind="pie")

# %%
#The number of pepole who satisfyed in sales,Finance,Hr,....etch
hr_Test.groupby("sales").mean()
# Out:
#                  Left  satisfaction_level  last_evaluation  number_project  \
# sales
# IT           0.222494            0.618142         0.716830        3.816626
# RandD        0.153748            0.619822         0.712122        3.853875
# accounting   0.265971            0.582151         0.717718        3.825293
# hr           0.290934            0.598809         0.708850        3.654939
# management   0.144444            0.621349         0.724000        3.860317
# marketing    0.236597            0.618601         0.715886        3.687646
# product_mng  0.219512            0.619634         0.714756        3.807095
# sales        0.244928            0.614447         0.709717        3.776329
# support      0.248991            0.618300         0.723109        3.803948
# technical    0.256250            0.607897         0.721099        3.877941
#
#              average_montly_hours  time_spend_company  Work_accident  \
# sales
# ...

# %%
hr_Test.groupby("Left").mean()
# Out:
#       satisfaction_level  last_evaluation  number_project  \
# Left
# 0               0.666810         0.715473        3.786664
# 1               0.440098         0.718113        3.855503
#
#       average_montly_hours  time_spend_company  Work_accident  \
# Left
# 0               199.060203            3.380032       0.175009
# 1               207.419210            3.876505       0.047326
#
#       promotion_last_5years
# Left
# 0                  0.026251
# 1                  0.005321

# %%
hr_Test.groupby("sales").mean().plot(kind="bar",bins=20)
plt.plot()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-74-d40290234397> in <module>()
# ----> 1 hr_Test.groupby("sales").mean().plot(kind="bar",bins=20)
#       2 plt.plot()
#
# C:\Users\Pawan\Anaconda3\lib\site-packages\pandas\plotting\_core.py in __call__(self, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    2618                           fontsize=fontsize, colormap=colormap, table=table,
#    2619                           yerr=yerr, xerr=xerr, secondary_y=secondary_y,
# -> 2620                           sort_columns=sort_columns, **kwds)
#    2621     __call__.__doc__ = plot_frame.__doc__
#    2622
#
# ...
