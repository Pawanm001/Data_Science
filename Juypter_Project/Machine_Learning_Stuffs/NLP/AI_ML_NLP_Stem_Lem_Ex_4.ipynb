# %%
from nltk import stem
from nltk.chunk import ne_chunk
from nltk.tokenize import word_tokenize
from nltk.tag import pos_tag
import io
from nltk.corpus import stopwords
from nltk.stem import SnowballStemmer

wn_lemat = stem.WordNetLemmatizer()

nltk.download('wordnet')
ps = SnowballStemmer ('english')
fd = open("C:\Users\Bhaskar\Documents\PythonScripts\NLPdataEx3&4-data_in.txt","r") 

stopWords = set(stopwords.words('english'))
#Read first message
msg = fd.readline()
wordsFiltered = []
while msg:
  print msg
#  words = (msg.lower()).split()
  words = word_tokenize(msg)
#  print words
#Create the list without stop words 
  for w in words:
     if w not in stopWords:
        wordsFiltered.append(w)
  print wordsFiltered
#stem the words in list
  for word_filtrd in wordsFiltered:
    if word_filtrd:
      print(ps.stem(word_filtrd))
      print (wn_lemat.lemmatize(word_filtrd))
#Clear list for next message    
  wordsFiltered[:] = []
# read next message
  msg = fd.readline()

fd.close()
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Bhaskar\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\wordnet.zip.
# Hello there, how are you? Weather is awesome. Its raining here now.
#
# ['Hello', ',', '?', 'Weather', 'awesome', '.', 'Its', 'raining', '.']
# hello
# Hello
# ,
# ,
# ?
# ?
# weather
# Weather
# awesom
# awesome
# .
# .
# it
# Its
# rain
# raining
# .
# .
# Hello Mr. Raja, how are you? Weather is awesome. Its raining here now.
#
# ['Hello', 'Mr.', 'Raja', ',', '?', 'Weather', 'awesome', '.', 'Its', 'raining', '.']
# hello
# Hello
# mr.
# Mr.
# raja
# Raja
# ,
# ,
# ?
# ?
# weather
# Weather
# awesom
# awesome
# .
# .
# it
# Its
# rain
# raining
# .
# .
# Hello Mr. Raja, how are you. Weather is bad. Its heavily raining here now.
#
# ['Hello', 'Mr.', 'Raja', ',', '.', 'Weather', 'bad', '.', 'Its', 'heavily', 'raining', '.']
# hello
# Hello
# mr.
# Mr.
# raja
# Raja
# ,
# ,
# .
# .
# weather
# Weather
# bad
# bad
# .
# .
# it
# Its
# ...
